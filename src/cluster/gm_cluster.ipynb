# %%
from sklearn.mixture import GaussianMixture
import pandas as pd

features = pd.read_csv(
    r"../../data/clean_market_data/features.csv", index_col=0)
features.head()
# Out:
#        2015-01-02  2015-01-05  2015-01-06  2015-01-07  2015-01-08  2015-01-09  \
# Tick
# CSCO    -0.897344   -0.951685   -0.331614    0.589535   -0.108935    0.433686
# ISRG    -1.000226   -1.608707   -0.689722   -0.217649    0.832386   -1.902180
# LBTYK   -0.820684   -4.690083   -0.021682   -0.777539   -0.602286   -0.325030
# VRTX     2.583978   -1.014147   -3.256118    1.548564    1.614755   -1.244445
# GILD    -0.241745    1.627471   -0.832741    0.171187    1.488095   -1.265454
#
#        2015-01-12  2015-01-13  2015-01-14  2015-01-15  ...  2021-10-18  \
# Tick                                                   ...
# CSCO     0.178569   -0.389928    0.287356   -2.420791  ...    0.272525
# ISRG     0.512597   -1.943607    2.695134   -2.007032  ...    0.596374
# LBTYK    0.108388   -0.021511    0.151843   -1.080847  ...    0.376973
# VRTX    -3.820831    0.166110    1.655125   -2.483855  ...   -0.931505
# GILD    -1.584984   -4.555719    3.395836   -1.913395  ...   -2.370368
#
# ...

# %%
gm_y = GaussianMixture(
    n_components=14, random_state=0).fit_predict(features)

gm_cluster = features.reset_index()
gm_cluster.insert(1, "Cluster", gm_y)

count_map = dict(gm_cluster['Cluster'].value_counts())
print(count_map)

gm_cluster['Cluster Weight'] = gm_cluster['Cluster'].map(count_map)

WEIGHT_TRESHOLD = int(gm_cluster.shape[0] / len(count_map))

gm_cluster = gm_cluster[gm_cluster['Cluster Weight']
                                    > WEIGHT_TRESHOLD]
gm_cluster.drop('Cluster Weight', axis=1, inplace=True)

print(gm_cluster['Cluster'].value_counts())

gm_cluster.to_csv(
    r'../../data/cluster_results/gm_cluster_result.csv')
# Out:
# {9: 35, 3: 24, 8: 13, 11: 11, 5: 2, 7: 2, 2: 1, 4: 1, 0: 1, 10: 1, 13: 1, 6: 1, 12: 1, 1: 1}
# 9     35
# 3     24
# 8     13
# 11    11
# Name: Cluster, dtype: int64
